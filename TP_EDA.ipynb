# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importación

# %%
data = pd.read_excel('datosRed.xlsx')

# %% [markdown]
# # Limpieza

# %% [markdown]
# # EDA
